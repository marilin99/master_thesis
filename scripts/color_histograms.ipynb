# %%
# %pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:02:02m
# Requirement already satisfied: numpy>=1.19.3 in /home/marilin/miniconda3/envs/automl_env/lib/python3.9/site-packages (from opencv-python) (1.23.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.68

# %%
import os.path
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Open the camera
#camera= cv2.VideoCapture(0)
PATH_1 = '/home/marilin/Documents/ESP/red_chan_cubic.png'
img = cv2.imread(PATH_1,0)
          
plt.plot(img.ravel())
  
#plt.hist(img.ravel(),256,[0,256]); plt.show();

# %%
len(np.where(img.ravel() >= 70)[0])
# Out:
# 363

# %%
img = cv2.imread(PATH_1)
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()
